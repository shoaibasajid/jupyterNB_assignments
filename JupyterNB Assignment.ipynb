# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shoaib Ahmad Sajid**
# </br>
# Software Engineer

# %% [markdown]
# *I am interested in data science because I want to switch my career from development to data scientist.*

# %% [markdown]
# ### multiply the values

# %%
print("the double of 2 is " ) 
2*2
# Out:
# the double of 2 is
# 4

# %% [markdown]
# <blockquote>in this cell number 6 I included the block quote as this is, also added the bullet lists and 2 hyperlinks in the bullet list</blockquote>
#
#
# - fist link [Google](https://www.google.com/)
# - [IBM](https://www.ibm.com/)
# - third link is missing
